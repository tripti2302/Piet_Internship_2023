# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import time
url='https://raw.githubusercontent.com/redashu/Datasets/master/PositionSalaries_Data.csv'
df=pd.read_csv(url)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
features=df.iloc[:,1:-1].values
labels=df.iloc[:,-1].values
lin_model=LinearRegression()
trained_model=lin_model.fit(features,labels)
predicted_model=lin_model.predict(features)
plt.xlabel('level of experience')
plt.ylabel('salary')
plt.title('company database')
plt.scatter(features,labels,marker='*',color='red')
plt.plot(features,predicted_model)
plt.grid()
plt.show()

trained_model.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
poly_model=PolynomialFeatures()
transform_data=poly_model.fit_transform(features)
#print(transform_data)
model=LinearRegression()
trained_model=model.fit(transform_data,labels)
#now let's try prediction
predicted_output=trained_model.predict(poly_model.fit_transform(features))
print(labels)
time.sleep(3)
print(predicted_output)
plt.xlabel('labels')
plt.ylabel('predicted_output')
plt.plot(labels,predicted_output)
plt.scatter(labels,predicted_output)
plt.grid()
plt.show()
# Out:
# [  45000   50000   60000   80000  110000  150000  200000  300000  500000
#  1000000]
# [118727.27272727  44151.51515151   8439.39393939  11590.90909091
#   53606.06060606 134484.84848485 254227.27272727 412833.33333333
#  610303.03030303 846636.36363636]

# %%
#python code to read email:real-time data_set
#logistic algo of machine learning
